-- %% [markdown]
-- # [dbo].[componentes_catalogo]

-- %%
/****** Object:  Table [dbo].[componentes_catalogo]    Script Date: 17-10-2025 18:39:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[componentes_catalogo](
	[componente_id] [int] IDENTITY(1,1) NOT NULL,
	[nombre_componente] [nvarchar](120) NOT NULL,
	[descripcion_componente] [nvarchar](400) NULL,
	[active] [bit] NOT NULL,
	[default_is_recyclable] [bit] NOT NULL,
	[default_is_reusable] [bit] NOT NULL,
	[default_is_sellable] [bit] NOT NULL,
	[default_is_hazardous] [bit] NOT NULL,
	[guidance_short] [nvarchar](200) NULL,
	[guidance_url] [nvarchar](400) NULL,
PRIMARY KEY CLUSTERED 
(
	[componente_id] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[nombre_componente] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[dispositivo_catalogo]

-- %%
/****** Object:  Table [dbo].[dispositivo_catalogo]    Script Date: 17-10-2025 18:39:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[dispositivo_catalogo](
	[dispositivo_id] [int] IDENTITY(1,1) NOT NULL,
	[nombre_dispositivo] [nvarchar](80) NOT NULL,
	[descripcion_dispositivo] [nvarchar](400) NULL,
	[example_image_url] [nvarchar](400) NULL,
	[active] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[dispositivo_id] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[nombre_dispositivo] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[dispositivo_componente_mapa]

-- %%
/****** Object:  Table [dbo].[dispositivo_componente_mapa]    Script Date: 17-10-2025 18:39:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[dispositivo_componente_mapa](
	[dispositivo_id] [int] NOT NULL,
	[componente_id] [int] NOT NULL,
 CONSTRAINT [PK_dcm] PRIMARY KEY CLUSTERED 
(
	[dispositivo_id] ASC,
	[componente_id] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[v_dispositivo_componentes]

-- %%
/****** Object:  View [dbo].[v_dispositivo_componentes]    Script Date: 17-10-2025 18:39:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE VIEW [dbo].[v_dispositivo_componentes] AS
SELECT
  d.nombre_dispositivo,
  c.componente_id,
  c.nombre_componente,
  c.descripcion_componente,
  c.default_is_recyclable AS is_recyclable,
  c.default_is_reusable   AS is_reusable,
  c.default_is_sellable   AS is_sellable,
  c.default_is_hazardous  AS is_hazardous,
  c.guidance_short,
  c.guidance_url
FROM dbo.dispositivo_componente_mapa m
JOIN dbo.dispositivo_catalogo d ON d.dispositivo_id = m.dispositivo_id
JOIN dbo.componentes_catalogo   c ON c.componente_id = m.componente_id;
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 17-10-2025 18:39:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](100) NOT NULL,
	[Correo] [nvarchar](100) NOT NULL,
	[Contraseña] [nvarchar](100) NOT NULL,
	[RegionUsuario] [nvarchar](100) NOT NULL,
	[ComunaUsuario] [nvarchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_comp_active]

-- %%
ALTER TABLE [dbo].[componentes_catalogo] ADD  CONSTRAINT [DF_comp_active]  DEFAULT ((1)) FOR [active]
GO

-- %% [markdown]
-- # [DF_comp_isrecycl]

-- %%
ALTER TABLE [dbo].[componentes_catalogo] ADD  CONSTRAINT [DF_comp_isrecycl]  DEFAULT ((0)) FOR [default_is_recyclable]
GO

-- %% [markdown]
-- # [DF_comp_isreus]

-- %%
ALTER TABLE [dbo].[componentes_catalogo] ADD  CONSTRAINT [DF_comp_isreus]  DEFAULT ((0)) FOR [default_is_reusable]
GO

-- %% [markdown]
-- # [DF_comp_issell]

-- %%
ALTER TABLE [dbo].[componentes_catalogo] ADD  CONSTRAINT [DF_comp_issell]  DEFAULT ((0)) FOR [default_is_sellable]
GO

-- %% [markdown]
-- # [DF_comp_ishaz]

-- %%
ALTER TABLE [dbo].[componentes_catalogo] ADD  CONSTRAINT [DF_comp_ishaz]  DEFAULT ((0)) FOR [default_is_hazardous]
GO

-- %% [markdown]
-- # [DF_disp_active]

-- %%
ALTER TABLE [dbo].[dispositivo_catalogo] ADD  CONSTRAINT [DF_disp_active]  DEFAULT ((1)) FOR [active]
GO

-- %% [markdown]
-- # [FK_dcm_component]

-- %%
ALTER TABLE [dbo].[dispositivo_componente_mapa]  WITH CHECK ADD  CONSTRAINT [FK_dcm_component] FOREIGN KEY([componente_id])
REFERENCES [dbo].[componentes_catalogo] ([componente_id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[dispositivo_componente_mapa] CHECK CONSTRAINT [FK_dcm_component]
GO

-- %% [markdown]
-- # [FK_dcm_device]

-- %%
ALTER TABLE [dbo].[dispositivo_componente_mapa]  WITH CHECK ADD  CONSTRAINT [FK_dcm_device] FOREIGN KEY([dispositivo_id])
REFERENCES [dbo].[dispositivo_catalogo] ([dispositivo_id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[dispositivo_componente_mapa] CHECK CONSTRAINT [FK_dcm_device]
GO
